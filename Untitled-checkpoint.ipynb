# %%
import sys
sys.path.insert(0, '../')
# %load_ext autoreload
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
# %matplotlib inline

from minisom import MiniSom
from sklearn.preprocessing import minmax_scale, scale
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
coronadata = pd.read_csv('datasets_602378_1084128_testingdataworldwide_April_15.csv')

# %%
country_codes = {'Afghanistan': 'AF',
 'Albania': 'AL',
 'Algeria': 'DZ',
 'Angola': 'AO',
 'Argentina': 'AR',
 'Armenia': 'AM',
 'Australia': 'AU',
 'Austria': 'AT',
 'Azerbaijan': 'AZ',
 'Bahrain': 'BH',
 'Bangladesh': 'BD',
 'Belarus': 'BY',
 'Belgium': 'BE',
 'Benin': 'BJ',
 'Bhutan': 'BT',
 'Bolivia': 'BO',
 'Bosnia and Herzegovina': 'BA',
 'Botswana': 'BW',
 'Brazil': 'BR',
 'Bulgaria': 'BG',
 'Burkina Faso': 'BF',
 'Burundi': 'BI',
 'Cambodia': 'KH',
 'Cameroon': 'CM',
 'Canada': 'CA',
 'Cape Verde': 'CV',
 'Central African Republic': 'CF',
 'Chad': 'TD',
 'Chile': 'CL',
 'China': 'CN',
 'Colombia': 'CO',
 'Comoros': 'KM',
 'Costa Rica': 'CR',
 'Croatia': 'HR',
 'Cuba': 'CU',
 'Cyprus': 'CY',
 'Czech Republic': 'CZ',
 'Democratic Republic of the Congo': 'CD',
 'Denmark': 'DK',
 'Djibouti': 'DJ',
 'Dominican Republic': 'DO',
 'Ecuador': 'EC',
 'Egypt': 'EG',
 'El Salvador': 'SV',
 'Equatorial Guinea': 'GQ',
 'Eritrea': 'ER',
 'Estonia': 'EE',
 'Ethiopia': 'ET',
 'Fiji': 'FJ',
 'Finland': 'FI',
 'France': 'FR',
 'Gabon': 'GA',
 'Gambia': 'GM',
 'Georgia': 'GE',
 'Germany': 'DE',
 'Ghana': 'GH',
 'Greece': 'GR',
 'Guatemala': 'GT',
 'Guinea': 'GN',
 'Guinea-Bissau': 'GW',
 'Guyana': 'GY',
 'Haiti': 'HT',
 'Honduras': 'HN',
 'Hong Kong': 'HK',
 'Hungary': 'HU',
 'Iceland': 'IS',
 'India': 'IN',
 'Indonesia': 'ID',
 'Iran': 'IR',
 'Iraq': 'IQ',
 'Ireland': 'IE',
 'Israel': 'IL',
 'Italy': 'IT',
 'Ivory Coast': 'IC',
 'Jamaica': 'JM',
 'Japan': 'JP',
 'Jordan': 'JO',
 'Kazakhstan': 'KZ',
 'Kenya': 'KE',
 'Kuwait': 'KW',
 'Kyrgyzstan': 'KG',
 'Laos': 'LA',
 'Latvia': 'LV',
 'Lebanon': 'LB',
 'Lesotho': 'LS',
 'Liberia': 'LR',
 'Libya': 'LY',
 'Lithuania': 'LT',
 'Luxembourg': 'LU',
 'Macedonia': 'MK',
 'Madagascar': 'MG',
 'Malawi': 'MW',
 'Malaysia': 'MY',
 'Mali': 'ML',
 'Malta': 'MT',
 'Mauritania': 'MR',
 'Mauritius': 'MU',
 'Mexico': 'MX',
 'Moldova': 'MD',
 'Mongolia': 'MN',
 'Montenegro': 'ME',
 'Morocco': 'MA',
 'Mozambique': 'MZ',
 'Myanmar': 'MM',
 'Namibia': 'NA',
 'Nepal': 'NP',
 'Netherlands': 'NL',
 'New Zealand': 'NZ',
 'North Macedonia': 'NM',
 'Nicaragua': 'NI',
 'Niger': 'NE',
 'Nigeria': 'NG',
 'North Korea': 'KP',
 'Norway': 'NO',
 'Oman': 'OM',
 'Pakistan': 'PK',
 'Palestine': 'PS',
 'Panama': 'PA',
 'Papua New Guinea': 'PG',
 'Paraguay': 'PY',
 'Peru': 'PE',
 'Philippines': 'PH',
 'Poland': 'PL',
 'Portugal': 'PT',
 'Qatar': 'QA',
 'Republic of China (Taiwan)': 'TW',
 'Republic of the Congo': 'CG',
 'Romania': 'RO',
 'Russia': 'RU',
 'Rwanda': 'RW',
 'Saudi Arabia': 'SA',
 'Senegal': 'SN',
 'Serbia': 'RS',
 'Sierra Leone': 'SL',
 'Singapore': 'SG',
 'Slovakia': 'SK',
 'Slovenia': 'SI',
 'South Africa': 'ZA',
 'S. Korea': 'KR',
 'Spain': 'ES',
 'Sri Lanka': 'LK',
 'Sudan': 'SD',
 'Suriname': 'SR',
 'Swaziland': 'SZ',
 'Sweden': 'SE',
 'Switzerland': 'CH',
 'Syria': 'SY',
 'Tajikistan': 'TJ',
 'Tanzania': 'TZ',
 'Thailand': 'TH',
 'Timor-Leste': 'TL',
 'Togo': 'TG',
 'Trinidad and Tobago': 'TT',
 'Tunisia': 'TN',
 'Turkey': 'TR',
 'Turkmenistan': 'TM',
 'Uganda': 'UG',
 'Ukraine': 'UA',
 'United Arab Emirates': 'AE',
 'United Kingdom': 'GB',
 'United States': 'US',
 'Uruguay': 'UY',
 'Uzbekistan': 'UZ',
 'Venezuela': 'VE',
 'Vietnam': 'VN',
 'Yemen': 'YE',
 'Zambia': 'ZM',
 'Zimbabwe': 'ZW',
 'British Virgin Islands': 'BRV',
                 'Saint Kitts and Nevis': 'SKAN',
                 'Faeroe Islands':'FI',
                 'French Guiana':'FG',
                 'Diamond Princess':'DPR',
                 'Channel Islands':'CHI',
                 'St. Vincent Grenadines':'STVG',
                 'Caribbean Netherlands':'CNI',
                 'Sao Tome and Principe':'STAP',
                 'Saint Pierre Miquelon':'SPM'
                 
                }

# %%
feature_names = ['Total Cases', 'Cases', 'Total Deaths',
                 'Deaths', 'Total Recovers', 'Active','Total Cases/1M pop','Deaths/1M pop','Total Test','Tests/1M pop']

X = coronadata[feature_names].values
X = scale(X)

size = 15
som = MiniSom(size, size, len(X[0]),
              neighborhood_function='gaussian', sigma=1.5,
              random_seed=1)

som.pca_weights_init(X)
som.train_random(X, 1000, verbose=True)
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-105-cc02832cf6bd> in <module>
#      10               random_seed=1)
#      11
# ---> 12 som.pca_weights_init(X)
#      13 som.train_random(X, 1000, verbose=True)
#
# ~\anaconda3\lib\site-packages\minisom.py in pca_weights_init(self, data)
#     360                   'One of the dimensions of the map is 1.'
#     361             warn(msg)
# --> 362         pc_length, pc = linalg.eig(cov(transpose(data)))
#     363         pc_order = argsort(-pc_length)
#     364         for i, c1 in enumerate(linspace(-1, 1, len(self._neigx))):
#
# <__array_function__ internals> in eig(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\linalg\linalg.py in eig(a)
#    1293     _assert_stacked_2d(a)
#    1294     _assert_stacked_square(a)
# -> 1295     _assert_finite(a)
#    1296     t, result_t = _commonType(a)
#    1297
#
# ~\anaconda3\lib\site-packages\numpy\linalg\linalg.py in _assert_finite(*arrays)
#     216     for a in arrays:
#     217         if not isfinite(a).all():
# --> 218             raise LinAlgError("Array must not contain infs or NaNs")
#     219
#     220 def _is_empty_2d(arr):
#
# LinAlgError: Array must not contain infs or NaNs

# %%
np.isnan(X).any()
# Out:
# True

# %%
X
# Out:
# array([[12.619,  7.754,  8.711, ...,  0.605, 11.019,  0.216],
#        [ 3.475,  4.642,  5.888, ...,  3.946,  1.875,  0.449],
#        [ 3.217,  3.393,  6.893, ...,  3.532,  3.729,  0.846],
#        ...,
#        [-0.199, -0.284, -0.203, ..., -0.265, -0.276, -0.454],
#        [-0.199, -0.284, -0.203, ..., -0.265, -0.276, -0.454],
#        [ 1.503, -0.221,  0.893, ..., -0.244, -0.276, -0.454]])

# %%
X = np.nan_to_num(X)

# %%
np.isnan(X).any()
# Out:
# False

# %%
size = 15
som = MiniSom(size, size, len(X[0]),
              neighborhood_function='gaussian', sigma=1.5,
              random_seed=1)

som.pca_weights_init(X)
som.train_random(X, 1000, verbose=True)
# Out:
#  [  741 / 1000 ]  74% - 0:00:00 left
#  [ 1000 / 1000 ] 100% - 0:00:00 left
#  quantization error: 0.3622648600389903

# %%
def shorten_country(c):
    if len(c) > 20:
        return country_codes[c]
    else:
        return c

country_map = som.labels_map(X, coronadata.Country)
    
plt.figure(figsize=(10, 10))
for p, countries in country_map.items():
    countries = list(countries)
    x = p[0] + .1
    y = p[1] - .3
    for i, c in enumerate(countries):
        off_set = (i+1)/len(countries) - 0.05
        plt.text(x, y+off_set, shorten_country(c),fontsize=10)
plt.pcolor(som.distance_map().T, cmap='gray_r', alpha=.2)
plt.xticks(np.arange(size+1))
plt.yticks(np.arange(size+1))
plt.grid()

legend_elements = [Patch(facecolor=clr,
                         edgecolor='w',
                         label=l) for l, clr in category_color.items()]
plt.legend(handles=legend_elements, loc='center left', bbox_to_anchor=(1, .95))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-111-23d9402cfdbd> in <module>
#      22 legend_elements = [Patch(facecolor=clr,
#      23                          edgecolor='w',
# ---> 24                          label=l) for l, clr in category_color.items()]
#      25 plt.legend(handles=legend_elements, loc='center left', bbox_to_anchor=(1, .95))
#      26 plt.show()
#
# NameError: name 'category_color' is not defined

# %%
X
# Out:
# array([[12.61914894,  7.7537937 ,  8.71107151, ...,  0.60462037,
#         11.01909846,  0.21606046],
#        [ 3.47501038,  4.64201905,  5.88815325, ...,  3.94583841,
#          1.87475754,  0.44907062],
#        [ 3.21691278,  3.39289728,  6.89327082, ...,  3.53216379,
#          3.72938164,  0.84630616],
#        ...,
#        [-0.1991676 , -0.28415322, -0.20254451, ..., -0.26515702,
#         -0.27593025, -0.45350087],
#        [-0.1991676 , -0.28415322, -0.20254451, ..., -0.26515702,
#         -0.27593025, -0.45350087],
#        [ 1.50301896, -0.22073203,  0.89305331, ..., -0.24394294,
#         -0.27593025, -0.45350087]])

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
X_a = ['Total Cases', 'Cases', 'Total Deaths',
                 'Deaths', 'Total Recovers', 'Active','Total Cases/1M pop','Deaths/1M pop','Total Test','Tests/1M pop']
X_arr = coronadata[X_a].values

# %%
X_arr
# Out:
# array([[6.197160e+05, 5.830000e+03, 2.719000e+04, ..., 8.200000e+01,
#         3.151093e+06, 9.520000e+03],
#        [1.776330e+05, 3.573000e+03, 1.857900e+04, ..., 3.970000e+02,
#         6.000000e+05, 1.283300e+04],
#        [1.651550e+05, 2.667000e+03, 2.164500e+04, ..., 3.580000e+02,
#         1.117404e+06, 1.848100e+04],
#        ...,
#        [1.000000e+00, 0.000000e+00, 0.000000e+00, ..., 0.000000e+00,
#         0.000000e+00, 0.000000e+00],
#        [1.000000e+00, 0.000000e+00, 0.000000e+00, ..., 0.000000e+00,
#         0.000000e+00, 0.000000e+00],
#        [8.229500e+04, 4.600000e+01, 3.342000e+03, ..., 2.000000e+00,
#         0.000000e+00, 0.000000e+00]])

# %%
scaler=MinMaxScaler(feature_range=(0,1))

# %%
rescaledX=scaler.fit_transform(X_arr)

# %%
np.set_printoptions(precision=3)

# %%
rescaledX[0:5,:]
# Out:
# array([[1.   , 1.   , 1.   , 1.   , 0.612, 1.   , 0.171, 0.077, 1.   ,
#         0.082],
#        [0.287, 0.613, 0.683, 0.283, 0.911, 0.162, 0.347, 0.374, 0.19 ,
#         0.11 ],
#        [0.266, 0.457, 0.796, 0.506, 0.49 , 0.193, 0.249, 0.337, 0.355,
#         0.159],
#        [0.231, 0.   , 0.578, 0.   , 0.37 , 0.181, 0.2  , 0.227, 0.106,
#         0.044],
#        [0.215, 0.162, 0.132, 0.085, 0.933, 0.105, 0.145, 0.041, 0.418,
#         0.135]])

# %%
np.isnan(rescaledX).any()
# Out:
# True

# %%
rescaledX = np.nan_to_num(rescaledX)

# %%
np.isnan(rescaledX).any()
# Out:
# False

# %%
size = 15
som = MiniSom(size, size, len(rescaledX[0]),
              neighborhood_function='gaussian', sigma=1.5,
              random_seed=1)

som.pca_weights_init(rescaledX)
som.train_random(rescaledX, 1000, verbose=True)
# Out:
#  [  848 / 1000 ]  85% - 0:00:00 left
#  [ 1000 / 1000 ] 100% - 0:00:00 left
#  quantization error: 0.036437609790556616

# %%
def shorten_country(c):
    if len(c) > 20:
        return country_codes[c]
    else:
        return c

country_map = som.labels_map(X, coronadata.Country)
    
plt.figure(figsize=(15, 15))
for p, countries in country_map.items():
    countries = list(countries)
    x = p[0] + .1
    y = p[1] - .3
    for i, c in enumerate(countries):
        off_set = (i+1)/len(countries) - 0.05
        plt.text(x, y+off_set, shorten_country(c),fontsize=10)
plt.pcolor(som.distance_map().T, cmap='gray_r', alpha=.2)
plt.xticks(np.arange(size+1))
plt.yticks(np.arange(size+1))
plt.grid()

legend_elements = [Patch(facecolor=clr,
                         edgecolor='w',
                         label=l) for l, clr in category_color.items()]
plt.legend(handles=legend_elements, loc='center left', bbox_to_anchor=(1, .95))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-100-f2ca835065b7> in <module>
#      22 legend_elements = [Patch(facecolor=clr,
#      23                          edgecolor='w',
# ---> 24                          label=l) for l, clr in category_color.items()]
#      25 plt.legend(handles=legend_elements, loc='center left', bbox_to_anchor=(1, .95))
#      26 plt.show()
#
# NameError: name 'category_color' is not defined

# %%
W = som.get_weights()
plt.figure(figsize=(10, 10))
for i, f in enumerate(feature_names):
    plt.subplot(3, 3, i+1)
    plt.title(f)
    plt.pcolor(W[:,:,i].T, cmap='coolwarm')
    plt.xticks(np.arange(size+1))
    plt.yticks(np.arange(size+1))
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-98-c86183074fb7> in <module>
#       2 plt.figure(figsize=(10, 10))
#       3 for i, f in enumerate(feature_names):
# ----> 4     plt.subplot(3, 3, i+1)
#       5     plt.title(f)
#       6     plt.pcolor(W[:,:,i].T, cmap='coolwarm')
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in subplot(*args, **kwargs)
#    1074
#    1075     fig = gcf()
# -> 1076     a = fig.add_subplot(*args, **kwargs)
#    1077     bbox = a.bbox
#    1078     byebye = []
#
# ~\anaconda3\lib\site-packages\matplotlib\figure.py in add_subplot(self, *args, **kwargs)
#    1412                     self._axstack.remove(ax)
#    1413
# -> 1414             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1415
#    1416         return self._add_axes_internal(key, a)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_subplots.py in __init__(self, fig, *args, **kwargs)
#      57                 if num < 1 or num > rows*cols:
#      58                     raise ValueError(
# ---> 59                         f"num must be 1 <= num <= {rows*cols}, not {num}")
#      60                 self._subplotspec = GridSpec(
#      61                         rows, cols, figure=self.figure)[int(num) - 1]
#
# ValueError: num must be 1 <= num <= 9, not 10

# %%
Z = np.zeros((size, size))
plt.figure(figsize=(8, 8))
for i in np.arange(som._weights.shape[0]):
    for j in np.arange(som._weights.shape[1]):
        feature = np.argmax(W[i, j , :])
        plt.plot([j+.5], [i+.5], 'o', color='C'+str(feature),
                 marker='s', markersize=24)

legend_elements = [Patch(facecolor='C'+str(i),
                         edgecolor='w',
                         label=f) for i, f in enumerate(feature_names)]

plt.legend(handles=legend_elements,
           loc='center left',
           bbox_to_anchor=(1, .95))
        
plt.xlim([0, size])
plt.ylim([0, size])
plt.show()

# %%
df = pd.read_csv('datasets_602378_1084128_testingdataworldwide_April_15.csv')

# %%
df.head()
# Out:
#    Country  Total Cases  Cases  Total Deaths  Deaths  Total Recovers  Active  \
# 0      USA       619716   5830         27190    1143         47639.0  544887
# 1    Spain       177633   3573         18579     324         70853.0   88201
# 2    Italy       165155   2667         21645     578         38092.0  105418
# 3   France       143303      0         15729       0         28805.0   98769
# 4  Germany       133154    944          3592      97         72600.0   56962
#
#    Total Cases/1M pop  Deaths/1M pop  Total Test  Tests/1M pop       Date
# 0              1872.0           82.0     3151093          9520  15-Apr-20
# 1              3799.0          397.0      600000         12833  15-Apr-20
# 2              2732.0          358.0     1117404         18481  15-Apr-20
# 3              2195.0          241.0      333807          5114  15-Apr-20
# 4              1589.0           43.0     1317887         15730  15-Apr-20

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 212 entries, 0 to 211
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Country             212 non-null    object
#  1   Total Cases         212 non-null    int64
#  2   Cases               212 non-null    int64
#  3   Total Deaths        212 non-null    int64
#  4   Deaths              212 non-null    int64
#  5   Total Recovers      211 non-null    float64
#  6   Active              212 non-null    int64
#  7   Total Cases/1M pop  212 non-null    float64
#  8   Deaths/1M pop       212 non-null    float64
#  9   Total Test          212 non-null    int64
#  10  Tests/1M pop        212 non-null    int64
#  11  Date                212 non-null    object
# dtypes: float64(3), int64(7), object(2)
# memory usage: 20.0+ KB
